# %%
import numpy as np
from pathlib import Path
import yaml
import matplotlib.pyplot as plt
import pandas as pd

# %%
# path = Path("../results/24-02-28_19-08-37-829356")

path = Path("../results/24-04-04_20-21-53-927126/")
path_metrics = path / "metrics"

# %%
def flatten_dictionary(cfg):
    def items(cfg):
        for k, v in cfg.items():
            if isinstance(v, dict):
                for sub_k, sub_v in items(v):
                    yield (f"{k}.{sub_k}", sub_v)
            else:
                yield (k, v)

    return dict(items(cfg))

# %%
cfg = yaml.load(open(path / "cfg.yaml", "r"), Loader=yaml.FullLoader)
cfg_flatten = flatten_dictionary(cfg)

df = pd.DataFrame(cfg_flatten, index=[0])

# %%
df
# Out:
#    batch_size         criterion              dataset  \
# 0          16  CrossEntropyLoss  CustomDefectDataSet
#
#                    dataset_test_params.data_csv_path  \
# 0  /dtu/eumcaerotrain/data/latest_dataset/test_fi...
#
#   dataset_test_params.dataset_parent_folder dataset_test_params.dataset_type  \
# 0    /dtu/eumcaerotrain/data/latest_dataset                  npz_image_based
#
#    dataset_test_params.event_encoding_method  dataset_test_params.img_size  \
# 0                                          2                            32
#
#    dataset_test_params.transform  \
# 0                          False
#
#                   dataset_train_params.data_csv_path  ... optimizer  \
# 0  /dtu/eumcaerotrain/data/latest_dataset/night_o...  ...      Adam
#
#   optimizer_params.lr  optimizer_params.weight_decay  path_to_save  \
# 0               0.001                         0.0005     ./results
#
#    saving_checkpoint          scheduler  scheduler_params.factor  \
# 0                 10  ReduceLROnPlateau                      0.5
#
#    scheduler_params.mode  scheduler_params.patience scheduler_params.threshold
# 0                    max                          5                      0.001
#
# [1 rows x 30 columns]

# %%
def get_best_score(metric, data, operation="min"):
    if operation == "min":
        op = np.argmin
    elif operation == "max":
        op = np.argmax
    else:
        raise ValueError(f"Operation {operation} not supported")

    epoch = op(data[metric])
    
    new_data = {"epoch": epoch, "metric_saved [metric | operation]": f"{metric} | {operation}"}
    for k, v in data.items():
        new_data[k] = v[epoch]
    
    df = pd.DataFrame(new_data, index=[0])
    return df

# %%
metrics = {}
for file in path_metrics.glob("*.npy"):
    metrics[file.stem] = np.load(file)

print(list(metrics.keys()))
# Out:
# ['train_accs', 'valid_losses', 'train_losses', 'valid_accs', 'f1_scores_train', 'f1_scores_valid']

# %%
df_metric = get_best_score("valid_losses", metrics, "min")
final_df = pd.concat([df, df_metric], axis=1)
    
final_df
# Out:
#    batch_size         criterion              dataset  \
# 0          16  CrossEntropyLoss  CustomDefectDataSet
#
#                    dataset_test_params.data_csv_path  \
# 0  /dtu/eumcaerotrain/data/latest_dataset/test_fi...
#
#   dataset_test_params.dataset_parent_folder dataset_test_params.dataset_type  \
# 0    /dtu/eumcaerotrain/data/latest_dataset                  npz_image_based
#
#    dataset_test_params.event_encoding_method  dataset_test_params.img_size  \
# 0                                          2                            32
#
#    dataset_test_params.transform  \
# 0                          False
#
#                   dataset_train_params.data_csv_path  ...  \
# 0  /dtu/eumcaerotrain/data/latest_dataset/night_o...  ...
#
#   scheduler_params.patience scheduler_params.threshold  epoch  \
# 0                         5                      0.001      3
#
#    metric_saved [metric | operation]  train_accs valid_losses  train_losses  \
# 0                 valid_losses | min   79.427083      0.53214      0.458009
#
#    valid_accs  f1_scores_train f1_scores_valid
# 0   75.706941         0.792267        0.748819
#
# [1 rows x 38 columns]

# %%
for k, v in metrics.items():
    plt.figure()
    plt.plot(v)
    plt.title(k)
    plt.xlabel("Epoch")
    plt.ylabel(k)
