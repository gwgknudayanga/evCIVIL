# %%
import os
base_path = "/dtu/eumcaerotrain/data/Image_Data/yolo_nas_img_dataset/Images/train/"
output_file_path = "/dtu/eumcaerotrain/data/Image_Data/yolo_nas_img_dataset/train_anns.txt"

files = os.listdir(base_path)
with open(output_file_path,"w") as f:
    for file in files:
        s_name = file.rsplit(".",1)[0]
        text_string = "labels/train/"+s_name+".txt" + "\n"
        print(text_string)
        #f.writelines(text_string)
# Out:
# labels/train/cracking63.txt
#
# labels/train/cracking485.txt
#
# labels/train/434_yang.txt
#
# labels/train/541_yang.txt
#
# labels/train/002_yang.txt
#
# labels/train/608_yang.txt
#
# labels/train/533_yang.txt
#
# labels/train/cracking083.txt
#
# labels/train/cracking443.txt
#
# labels/train/cracking372.txt
#
# labels/train/629_yang.txt
#
# labels/train/cracking223.txt
#
# labels/train/cracking162.txt
#
# labels/train/cracking_joint012.txt
#
# labels/train/cracking25.txt
#
# labels/train/033_yang.txt
#
# labels/train/cracking0126.txt
#
# labels/train/cracking0102135.txt
#
# labels/train/cracking120.txt
#
# labels/train/cracking0102.txt
#
# labels/train/brick_cracking07.txt
#
# labels/train/455_yang.txt
#
# labels/train/557_yang.txt
#
# labels/train/cracks0024.txt
#
# labels/train/geopolimery-w-budownictwie.txt
#
# labels/train/376_yang.txt
#
# labels/train/cracking027.txt
#
# labels/train/794_yang.txt
#
# labels/train/783_yang.txt
#
# labels/train/018_yang.txt
#
# ...
